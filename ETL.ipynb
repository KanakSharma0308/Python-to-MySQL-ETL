# %%
pip install sqlalchemy mysql-connector-python pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\hp\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\hp\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
pip install cryptography  pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\hp\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
import os
import requests as rq
import json
import pandas as pd
import pymysql
from sqlalchemy import create_engine
from dotenv import load_dotenv

# %%
api="http://api.football-data.org/v4/competitions"
api_Key="e088f77b0f8045c79715fe7fc1e961ab"

# %%
season:2021
querystring={"season":2021}

# %%
headers={
"X-Auth-Token": "e088f77b0f8045c79715fe7fc1e961ab"}

# %%
base_url=rq.get(url=api,headers=headers)

# %%
data=base_url.json()
print(data)
# Out:
# {'count': 13, 'filters': {'client': 'Kanak Sharma'}, 'competitions': [{'id': 2013, 'area': {'id': 2032, 'name': 'Brazil', 'code': 'BRA', 'flag': 'https://crests.football-data.org/764.svg'}, 'name': 'Campeonato Brasileiro Série A', 'code': 'BSA', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/bsa.png', 'plan': 'TIER_ONE', 'currentSeason': {'id': 2474, 'startDate': '2026-01-28', 'endDate': '2026-12-02', 'currentMatchday': 4, 'winner': None}, 'numberOfAvailableSeasons': 10, 'lastUpdated': '2024-09-13T16:55:53Z'}, {'id': 2016, 'area': {'id': 2072, 'name': 'England', 'code': 'ENG', 'flag': 'https://crests.football-data.org/770.svg'}, 'name': 'Championship', 'code': 'ELC', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/ELC.png', 'plan': 'TIER_ONE', 'currentSeason': {'id': 2416, 'startDate': '2025-08-08', 'endDate': '2026-12-29', 'currentMatchday': 35, 'winner': None}, 'numberOfAvailableSeasons': 9, 'lastUpdated': '2024-09-13T16:51:18Z'}, {'id': 2021, 'area': {
# ...

# %%
formatted_data=json.dumps(data,indent=4)
print(formatted_data)
# Out:
# {
#     "count": 13,
#     "filters": {
#         "client": "Kanak Sharma"
#     },
#     "competitions": [
#         {
#             "id": 2013,
#             "area": {
#                 "id": 2032,
#                 "name": "Brazil",
#                 "code": "BRA",
#                 "flag": "https://crests.football-data.org/764.svg"
#             },
#             "name": "Campeonato Brasileiro S\u00e9rie A",
#             "code": "BSA",
#             "type": "LEAGUE",
#             "emblem": "https://crests.football-data.org/bsa.png",
#             "plan": "TIER_ONE",
#             "currentSeason": {
#                 "id": 2474,
#                 "startDate": "2026-01-28",
#                 "endDate": "2026-12-02",
#                 "currentMatchday": 4,
#                 "winner": null
#             },
#             "numberOfAvailableSeasons": 10,
#             "lastUpdated": "2024-09-13T16:55:53Z"
#         },
#         {
#             "id": 2016,
#             "area": {
# ...

# %%
competitions=data["competitions"]
competitions
# Out:
# [{'id': 2013,
#   'area': {'id': 2032,
#    'name': 'Brazil',
#    'code': 'BRA',
#    'flag': 'https://crests.football-data.org/764.svg'},
#   'name': 'Campeonato Brasileiro Série A',
#   'code': 'BSA',
#   'type': 'LEAGUE',
#   'emblem': 'https://crests.football-data.org/bsa.png',
#   'plan': 'TIER_ONE',
#   'currentSeason': {'id': 2474,
#    'startDate': '2026-01-28',
#    'endDate': '2026-12-02',
#    'currentMatchday': 4,
#    'winner': None},
#   'numberOfAvailableSeasons': 10,
#   'lastUpdated': '2024-09-13T16:55:53Z'},
#  {'id': 2016,
#   'area': {'id': 2072,
#    'name': 'England',
#    'code': 'ENG',
#    'flag': 'https://crests.football-data.org/770.svg'},
#   'name': 'Championship',
#   'code': 'ELC',
#   'type': 'LEAGUE',
#   'emblem': 'https://crests.football-data.org/ELC.png',
#   'plan': 'TIER_ONE',
#   'currentSeason': {'id': 2416,
#    'startDate': '2025-08-08',
#    'endDate': '2026-12-29',
#    'currentMatchday': 35,
#    'winner': None},
# ...

# %%
competitions[1]
# Out:
# {'id': 2016,
#  'area': {'id': 2072,
#   'name': 'England',
#   'code': 'ENG',
#   'flag': 'https://crests.football-data.org/770.svg'},
#  'name': 'Championship',
#  'code': 'ELC',
#  'type': 'LEAGUE',
#  'emblem': 'https://crests.football-data.org/ELC.png',
#  'plan': 'TIER_ONE',
#  'currentSeason': {'id': 2416,
#   'startDate': '2025-08-08',
#   'endDate': '2026-12-29',
#   'currentMatchday': 35,
#   'winner': None},
#  'numberOfAvailableSeasons': 9,
#  'lastUpdated': '2024-09-13T16:51:18Z'}

# %%
column_name=data["competitions"][2]['area']
column_name
# Out:
# {'id': 2072,
#  'name': 'England',
#  'code': 'ENG',
#  'flag': 'https://crests.football-data.org/770.svg'}

# %%
column=[ i for i in column_name]
print(column)
# Out:
# ['id', 'name', 'code', 'flag']

# %%
df=pd.DataFrame(columns=column)

# %%
df
# Out:
# Empty DataFrame
# Columns: [id, name, code, flag]
# Index: []

# %%
length=len(data["competitions"])
print(length)
# Out:
# 13

# %%
for i in range (0,12):
 column_data=[competitions[i]['area'][j] for j in competitions[i]['area']]
 length=len(df)
 df.loc[length]=column_data

# %%
df
# Out:
#       id           name code                                       flag
# 0   2032         Brazil  BRA   https://crests.football-data.org/764.svg
# 1   2072        England  ENG   https://crests.football-data.org/770.svg
# 2   2072        England  ENG   https://crests.football-data.org/770.svg
# 3   2077         Europe  EUR   https://crests.football-data.org/EUR.svg
# 4   2077         Europe  EUR   https://crests.football-data.org/EUR.svg
# 5   2081         France  FRA   https://crests.football-data.org/773.svg
# 6   2088        Germany  DEU   https://crests.football-data.org/759.svg
# 7   2114          Italy  ITA   https://crests.football-data.org/784.svg
# 8   2163    Netherlands  NLD  https://crests.football-data.org/8601.svg
# 9   2187       Portugal  POR   https://crests.football-data.org/765.svg
# 10  2220  South America  SAM   https://crests.football-data.org/CLI.svg
# 11  2224          Spain  ESP   https://crests.football-data.org/760.svg

# %%
MYSQL_HOST="localhost"
MYSQL_PORT="3306"
MYSQL_USER="root"
MYSQL_PASSWORD="Root_23"
MYSQL_DATABASE="football_database"

# %%
connection_url=f"mysql+mysqlconnector://{MYSQL_USER}:{MYSQL_PASSWORD}@{MYSQL_HOST}/{MYSQL_DATABASE}"

# %%
engine=create_engine(connection_url)
print("completed")
# Out:
# completed

# %%
connection_url="mysql+pymysql://root:Root_123@localhost/football_database"  
#charset=utf8mb4"
engine=create_engine(connection_url)
#,connect_args={'auth_plugin': 'mysql_native_password'})
try:
 df.to_sql("standings",
 con=engine,
 if_exists="replace", 
 index=False)
 print(" Data loaded")
except Exception as e:
 print(f"Error: {e}")
# Out:
#  Data loaded
